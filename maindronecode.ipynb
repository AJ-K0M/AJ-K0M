# %%
from google.colab import files

uploaded = files.upload()  # Choose the ColabVersion.zip file from your computer
# Out:
#      <input type="file" id="files-dc774a7e-35b6-4147-a2a3-113730cad6f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc774a7e-35b6-4147-a2a3-113730cad6f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

with zipfile.ZipFile("ColabVersion.zip", 'r') as zip_ref:
    zip_ref.extractall("ColabVersion")

os.chdir("ColabVersion")  # Move into the project folder

# %%
# !pip install cryptography pandas numpy joblib

# %%
# !python3 main_code.py
# Out:
# Running in standalone mode. Please enter starting point coordinates:
# Starting latitude: 40.7555
# Starting longitude: -73.9739
# Enter the maximum allowed distance in miles: 1
# Enter the time window size (number of GPS points to consider): 10
# Starting GPS spoofing detection...
#
# === GPS Spoofing Detection System ===
# 1: Drone GPS data
# 2: Manual GPS input
# 3: Replay mode (from log file)
# 4: View performance metrics
# 5: Exit
#
# Choose option (1-5): 3
#
# === GPS Log Replay Mode ===
# Enter GPS log file path (or press enter for default 'logs/gps_log.csv'): logs/nyc_gps_log_outside.csv
# Simulate spoofing? (y/n): y
# Spoofing simulation types:
# 1. Gradual drift
# 2. Sudden jump
# 3. Satellite count manipulation
# 4. Layered spoofing (drift + satellite + jump)
# Choose simulation type (1-4): 1
# Enter the index to start spoofing (0 to 9): 0
# Enter spoofing magnitude for drift (default 0.010765): 0.001
# ✅ Applied gradual drift simulation from index 0
#
# ...
